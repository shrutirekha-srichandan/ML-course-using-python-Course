# %% [markdown]
# # Day 15

# %%
import pandas  as pd
import numpy   as np

# %%
df = pd.read_excel("Dataset\Day15_Dataset.xlsx", sheet_name="Sheet1")
df
# Out:
#          Day  Temperature  Windspeed   Event
# 0 2025-01-01         32.0       44.0   Rainy
# 1 2025-01-02          0.0       57.0     NaN
# 2 2025-01-03         27.0       67.0  Cloudy
# 3 2025-01-04         29.0       46.0   Sunny
# 4 2025-01-05          NaN        NaN     NaN
# 5 2025-01-06         34.0       56.0   Sunny
# 6 2025-01-07          0.0       78.0  Cloudy
# 7 2025-01-08         38.0      100.0   Sunny
# 8 2025-01-09          NaN       35.0     NaN

# %%
df.columns
# Out:
# Index(['Day', 'Temperature', 'Windspeed', 'Event'], dtype='object')

# %%
# df.columns.str.strip() # Remove leading and trailing spaces from column names
df.columns = df.columns.str.strip() # Assign cleaned column names back to the DataFrame
df.columns
# Out:
# Index(['Day', 'Temperature', 'Windspeed', 'Event'], dtype='object')

# %%
type(df.Day[0]) #type of the first element in the Day column
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# df.set_index("Day", inplace=True) #set "Day" as the index
df1= df.set_index("Day")
df1
# Out:
#             Temperature  Windspeed   Event
# Day
# 2025-01-01         32.0       44.0   Rainy
# 2025-01-02          0.0       57.0     NaN
# 2025-01-03         27.0       67.0  Cloudy
# 2025-01-04         29.0       46.0   Sunny
# 2025-01-05          NaN        NaN     NaN
# 2025-01-06         34.0       56.0   Sunny
# 2025-01-07          0.0       78.0  Cloudy
# 2025-01-08         38.0      100.0   Sunny
# 2025-01-09          NaN       35.0     NaN

# %%
new_df = df.fillna(0)  # fill NaN values with 0
new_df
# Out:
#          Day  Temperature  Windspeed   Event
# 0 2025-01-01         32.0       44.0   Rainy
# 1 2025-01-02          0.0       57.0       0
# 2 2025-01-03         27.0       67.0  Cloudy
# 3 2025-01-04         29.0       46.0   Sunny
# 4 2025-01-05          0.0        0.0       0
# 5 2025-01-06         34.0       56.0   Sunny
# 6 2025-01-07          0.0       78.0  Cloudy
# 7 2025-01-08         38.0      100.0   Sunny
# 8 2025-01-09          0.0       35.0       0

# %%
new_df = df.fillna(
    {
        "Temperature": 0,
        "Windspeed": 0,
        "Event": "No Event"
    }
) # fill NaN values with specified values for each column
new_df
# Out:
#          Day  Temperature  Windspeed     Event
# 0 2025-01-01         32.0       44.0     Rainy
# 1 2025-01-02          0.0       57.0  No Event
# 2 2025-01-03         27.0       67.0    Cloudy
# 3 2025-01-04         29.0       46.0     Sunny
# 4 2025-01-05          0.0        0.0  No Event
# 5 2025-01-06         34.0       56.0     Sunny
# 6 2025-01-07          0.0       78.0    Cloudy
# 7 2025-01-08         38.0      100.0     Sunny
# 8 2025-01-09          0.0       35.0  No Event

# %%
df
# Out:
#          Day  Temperature  Windspeed   Event
# 0 2025-01-01         32.0       44.0   Rainy
# 1 2025-01-02          0.0       57.0     NaN
# 2 2025-01-03         27.0       67.0  Cloudy
# 3 2025-01-04         29.0       46.0   Sunny
# 4 2025-01-05          NaN        NaN     NaN
# 5 2025-01-06         34.0       56.0   Sunny
# 6 2025-01-07          0.0       78.0  Cloudy
# 7 2025-01-08         38.0      100.0   Sunny
# 8 2025-01-09          NaN       35.0     NaN

# %%
new_df = df.ffill()  # forward fill NaN values
new_df
# Out:
#          Day  Temperature  Windspeed   Event
# 0 2025-01-01         32.0       44.0   Rainy
# 1 2025-01-02          0.0       57.0   Rainy
# 2 2025-01-03         27.0       67.0  Cloudy
# 3 2025-01-04         29.0       46.0   Sunny
# 4 2025-01-05         29.0       46.0   Sunny
# 5 2025-01-06         34.0       56.0   Sunny
# 6 2025-01-07          0.0       78.0  Cloudy
# 7 2025-01-08         38.0      100.0   Sunny
# 8 2025-01-09         38.0       35.0   Sunny

# %%
new_df = df.replace(0, np.nan)  # replace 0 with NaN values and then forward fill
new_df
# Out:
#          Day  Temperature  Windspeed   Event
# 0 2025-01-01         32.0       44.0   Rainy
# 1 2025-01-02          NaN       57.0     NaN
# 2 2025-01-03         27.0       67.0  Cloudy
# 3 2025-01-04         29.0       46.0   Sunny
# 4 2025-01-05          NaN        NaN     NaN
# 5 2025-01-06         34.0       56.0   Sunny
# 6 2025-01-07          NaN       78.0  Cloudy
# 7 2025-01-08         38.0      100.0   Sunny
# 8 2025-01-09          NaN       35.0     NaN

# %%
new_df=df.replace(0, np.nan).ffill() # replace 0 with NaN values and then forward fill
new_df
# Out:
#          Day  Temperature  Windspeed   Event
# 0 2025-01-01         32.0       44.0   Rainy
# 1 2025-01-02         32.0       57.0   Rainy
# 2 2025-01-03         27.0       67.0  Cloudy
# 3 2025-01-04         29.0       46.0   Sunny
# 4 2025-01-05         29.0       46.0   Sunny
# 5 2025-01-06         34.0       56.0   Sunny
# 6 2025-01-07         34.0       78.0  Cloudy
# 7 2025-01-08         38.0      100.0   Sunny
# 8 2025-01-09         38.0       35.0   Sunny

# %%
n=df.replace(0, np.nan).ffill().describe()
n
# Out:
#                        Day  Temperature   Windspeed
# count                    9     9.000000    9.000000
# mean   2025-01-05 00:00:00    32.555556   58.777778
# min    2025-01-01 00:00:00    27.000000   35.000000
# 25%    2025-01-03 00:00:00    29.000000   46.000000
# 50%    2025-01-05 00:00:00    32.000000   56.000000
# 75%    2025-01-07 00:00:00    34.000000   67.000000
# max    2025-01-09 00:00:00    38.000000  100.000000
# std                    NaN     3.876568   20.179060

# %%
dataframe2 = pd.read_excel("Dataset\Day15_Dataset2.xlsx", sheet_name="Sheet1")
dataframe2.columns = dataframe2.columns.str.strip()  # Clean column names
dataframe2
# Out:
#          Day  Temperature Windspeed   Event
# 0 2025-01-01         32.0    44KMPH   Rainy
# 1 2025-01-02          0.0    57KMPH     NaN
# 2 2025-01-03         27.0    67KMPH  Cloudy
# 3 2025-01-04         29.0    46KMPH   Sunny
# 4 2025-01-05          NaN   NaNKMPH     NaN
# 5 2025-01-06         34.0    56KMPH   Sunny
# 6 2025-01-07          0.0    78KMPH  Cloudy
# 7 2025-01-08         38.0   100KMPH   Sunny
# 8 2025-01-09          NaN    35KMPH     NaN

# %%
new_df = df.replace({
    "Temperature":"[A-Za-z]",
    "Windspeed":"[A-Za-z]",
    "Event":"[A-Za-z]"
}, "", regex=True) # Replace alphabetic characters with an empty string
new_df
# Out:
#          Day  Temperature  Windspeed Event
# 0 2025-01-01         32.0       44.0
# 1 2025-01-02          0.0       57.0   NaN
# 2 2025-01-03         27.0       67.0
# 3 2025-01-04         29.0       46.0
# 4 2025-01-05          NaN        NaN   NaN
# 5 2025-01-06         34.0       56.0
# 6 2025-01-07          0.0       78.0
# 7 2025-01-08         38.0      100.0
# 8 2025-01-09          NaN       35.0   NaN

# %%
dataframe1 = pd.DataFrame({
    "marks":["poor","average","good","excellent"],
    "student":['john','jane',"doe","smith"]
}) #create a new Dataframe
dataframe1
# Out:
#        marks student
# 0       poor    john
# 1    average    jane
# 2       good     doe
# 3  excellent   smith

# %%
dataframe1.replace(['poor','average','good','excellent'],['F','C','B','A'])
#replace the values in dataframe
# Out:
#   marks student
# 0     F    john
# 1     C    jane
# 2     B     doe
# 3     A   smith

# %%
dataframe_3 = pd.read_excel("Dataset/Day15_Dataset3.xlsx", sheet_name="Sheet1")
dataframe_3.columns = dataframe_3.columns.str.strip()  # Clean column names
dataframe_3
# Out:
#          Date  City  Temperature
# 0  2000-01-01  BBSR           35
# 1  2000-01-02  BBSR           34
# 2  2000-01-03  BBSR           32
# 3  2000-01-04  BBSR           34
# 4  2000-01-05  BBSR           32
# 5  2000-01-06   CTC           40
# 6  2000-01-07   CTC           43
# 7  2000-01-08   CTC           41
# 8  2000-01-09   CTC           35
# 9  2000-01-10   CTC           43
# 10 2000-01-11   CTC           32
# 11 2000-01-12   RKL           43
# 12 2000-01-13   RKL           23
# 13 2000-01-14   RKL           34
# 14 2000-01-15   RKL           33

# %%
g=dataframe_3.groupby("City") #group by city
for City, group in g: #iterate over the groups
    print(f"City:{City}"),
    print(group),
# Out:
# City:BBSR
#         Date  City  Temperature
# 0 2000-01-01  BBSR           35
# 1 2000-01-02  BBSR           34
# 2 2000-01-03  BBSR           32
# 3 2000-01-04  BBSR           34
# 4 2000-01-05  BBSR           32
# City:CTC
#          Date City  Temperature
# 5  2000-01-06  CTC           40
# 6  2000-01-07  CTC           43
# 7  2000-01-08  CTC           41
# 8  2000-01-09  CTC           35
# 9  2000-01-10  CTC           43
# 10 2000-01-11  CTC           32
# City:RKL
#          Date City  Temperature
# 11 2000-01-12  RKL           43
# 12 2000-01-13  RKL           23
# 13 2000-01-14  RKL           34
# 14 2000-01-15  RKL           33

# %%
dataframe_3.groupby("City").get_group("BBSR")
# Out:
#         Date  City  Temperature
# 0 2000-01-01  BBSR           35
# 1 2000-01-02  BBSR           34
# 2 2000-01-03  BBSR           32
# 3 2000-01-04  BBSR           34
# 4 2000-01-05  BBSR           32

# %%
g.max() # Maximum value in each group
# Out:
#            Date  Temperature
# City
# BBSR 2000-01-05           35
# CTC  2000-01-11           43
# RKL  2000-01-15           43

# %%
g.mean() # Mean value in each group
# Out:
#                     Date  Temperature
# City
# BBSR 2000-01-03 00:00:00        33.40
# CTC  2000-01-08 12:00:00        39.00
# RKL  2000-01-13 12:00:00        33.25

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
g = dataframe_3.groupby('City')['Temperature'].mean()
colors = ['orange', 'blue', 'green'] # Define colors for each group

g.plot(kind='bar',color = colors,title = "Mean Temperature By City")
plt.ylabel("Temperature")
plt.xlabel("City")
plt.show()
